# %%
import numpy as np
import random
import argparse
from collections import namedtuple
from collections import deque
import math

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms

import gym
from environment import Environment

# %%
# parser
parser = argparse.ArgumentParser(description="DS595/CS525 RL Project 3")
parser.add_argument('--env_name', default=None, help='environment name')
parser.add_argument('--train_dqn', action='store_true', help='whether train DQN')
parser.add_argument('--test_dqn', action='store_true', help='whether test DQN')
args = parser.parse_args(args=[])

# %%
env_name = 'BreakoutNoFrameskip-v4'
env = Environment(env_name, args, atari_wrapper=True)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
# /usr/local/lib/python3.6/dist-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)

# %% [markdown]
# # Network

# %%
class DQN(nn.Module):
    """Initialize a deep Q-learning network
    
    Hints:
    -----
        Original paper for DQN
    https://storage.googleapis.com/deepmind-data/assets/papers/DeepMindNature14236Paper.pdf
    
    This is just a hint. You can build your own structure.
    """
    def __init__(self, ALPHA):
        """
        You can add additional arguments as you need.
        In the constructor we instantiate modules and assign them as
        member variables.
        """
        super(DQN, self).__init__()
        ###########################
        # YOUR IMPLEMENTATION HERE #
        self.conv1 = nn.Sequential(
            nn.Conv2d(4,32, kernel_size=8, stride=4),
            nn.ReLU())
        
        self.conv2 = nn.Sequential(
            nn.Conv2d(32,64, kernel_size=4, stride=2),
            nn.ReLU())
        
        self.conv3 = nn.Sequential(
            nn.Conv2d(64,64, kernel_size=3, stride=1),
            nn.ReLU())
        
        self.fc1 = nn.Linear(64*7*7, 512)
        self.fc2 = nn.Linear(512, 4) # (input, output) = (4 actions)

        self.optimizer = optim.RMSprop(self.parameters(), lr=ALPHA)
        self.loss = nn.MSELoss() 

        self.device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
        self.to(self.device)
        
    def forward(self, observation): # x
        """
        In the forward function we accept a Tensor of input data and we must return
        a Tensor of output data. We can use Modules defined in the constructor as
        well as arbitrary operators on Tensors.
        """
        ###########################
        # YOUR IMPLEMENTATION HERE #
        # frame = frame[30:200, 5:155,:] #Image cropping to speed up
        # observation = x
        
#         if(len(observation) == 1):
#         observation = torch.Tensor(observation).unsqueeze(1)
#         print(observation.size())
        observation = torch.Tensor(observation).to(self.device) 
#         observation = observation.reshape(observation.size(0),-1) # Shrinking the image
        observation = self.conv1(observation)
        observation = self.conv2(observation)
        observation = self.conv3(observation)
        observation = observation.reshape(observation.size(0),-1) #Flattenning the sequence of image
        observation = self.fc1(observation)
        action = self.fc2(observation)
        
        ###########################
        return action #x

# %% [markdown]
# # Agent

# %%
Transition = namedtuple('Transition', ('state', 'action', 'next_action', 'reward'))

class Agent_DQN():
    def __init__(self, env, args):
        """
        Initialize everything you need here.
        
        For example: 
            paramters for neural network  
            initialize Q net and target Q net
            parameters for repaly buffer
            parameters for q-learning; decaying epsilon-greedy
            ...
        """
        # Parameters for q-learning
        self.GAMMA = 0.95
        self.EPSILON = 0.99
        self.EPS_START = self.EPSILON
        self.EPS_END = 0.05 
        self.EPS_DECAY = 10
        self.ALPHA = 0.003
        self.TARGET_UPDATE = 32
        # self.REPLACE = 10000
        self.actionSpace = [0,1,2,3]

        # Parameters for Replay Buffer
        self.CAPACITY = 100 # Memory size
        self.memory = deque(maxlen=self.CAPACITY) #namedtuple to be used
        self.position = 0
        self.memCntr = 0 # Total sample stored, len(memory) 
        self.steps = 0
        
        self.storeEpsilon = []
        
        self.learn_step_counter = 0
        self.batch_size = 32

        super(Agent_DQN,self).__init__()
        ###########################
        # YOUR IMPLEMENTATION HERE #
        # nAction = env.action_space.n
        
        # Setup device 
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        print('Using device: ', device)
        #Initial Q
        self.policy_net = DQN(self.ALPHA).to(device) # Behavior Q 
        self.target_net = DQN(self.ALPHA).to(device) # Target Q 
        
        print('hyperparameters and network initialized')
        
        if args.test_dqn:
            #you can load your model here
            print('loading trained model')
            policy_net.load_state_dict(torch.load('test'))
            ###########################
            # YOUR IMPLEMENTATION HERE #
            
    def init_game_setting(self):
        """
        Testing function will call this function at the begining of new game
        Put anything you want to initialize if necessary.
        If no parameters need to be initialized, you can leave it as blank.
        """
        ###########################
        # YOUR IMPLEMENTATION HERE #
        
        ###########################
        pass    
    
    def make_action(self, observation, test=True):
        """
        Return predicted action of your agent
        Input:
            observation: np.array
                stack 4 last preprocessed frames, shape: (84, 84, 4)
        Return:
            action: int
                the predicted action from trained model
        """
        ###########################
        # YOUR IMPLEMENTATION HERE #
        rand = np.random.random()
        observation = torch.Tensor(observation).unsqueeze(0)
        actions = self.policy_net.forward(observation)
        
#         print(actions[0])
        
        if rand < 1 - self.EPSILON:
            action = torch.argmax(actions[0]).item()
        else:
            action = np.random.choice(self.actionSpace)

        # Update exploration factor
        self.EPSILON = self.EPS_END + (self.EPS_START - self.EPS_END) *\
            math.exp(-1 * self.steps/self.EPS_DECAY)
        
        self.storeEpsilon.append(self.EPSILON)
        self.steps += 1 

        ###########################
        return action
    
    def push(self, *args):
        """ You can add additional arguments as you need. 
        Push new data to buffer and remove the old one if the buffer is full.
        
        Hints:
        -----
            you can consider deque(maxlen = 10000) list
        """
        ###########################
        # YOUR IMPLEMENTATION HERE #
        if len(self.memory) == self.CAPACITY:
            self.memory.popleft()
        self.memory.append(Transition(*args)) 
        self.position = (self.position + 1) % self.CAPACITY #increment position to store next transitions
        self.memCntr = len(self.memory)
        
    def replay_buffer(self):
        """ You can add additional arguments as you need.
        Select batch from buffer.
        """
        ###########################
        # YOUR IMPLEMENTATION HERE #
        
        # generate batch of random sampled transitions from memory
        return random.sample(self.memory, self.batch_size)
    
    def get_screen(self,observation):
        meaned = np.mean(observation, axis=2).astype(np.uint8)
        print(np.shape(meaned))
        return meaned
    
    def optimize_model(self):
        self.target_net.optimizer.zero_grad()

        transitions = np.array(self.replay_buffer())
        Qstate = self.policy_net.forward(list(transitions[:,0])).to(self.policy_net.device)
        QNextState = self.policy_net.forward(list(transitions[:,2])).to(self.policy_net.device)                
        
        maxActions = torch.argmax(QNextState, dim=1).to(self.policy_net.device)
        rewards = torch.Tensor(list(transitions[:,3])).to(self.policy_net.device)

        Qtarget = Qstate
        Qtarget[:,maxActions] = rewards + self.GAMMA*torch.max(QNextState[1])

        loss = self.policy_net.loss(Qtarget,Qstate).to(self.policy_net.device)
#         print('loss:', loss)
        loss.backward()
        self.policy_net.optimizer.step()
        
        
    def train(self):
        nEpisodes = 1000
        self.scores = []
        
        for iEpisode in range(nEpisodes):
            print('Episode: ', iEpisode)
            # Initialize environment and state
            state = env.reset()
            state = state.transpose(2,0,1)
            done = False
            score = 0
            
            while not done:
                if self.memCntr < self.batch_size:
                    action = env.get_random_action()
                else:
                    action = self.make_action(state)
                    
                nextState, reward, done, info = env.step(action)
                nextState = nextState.transpose(2,0,1)
                # Add transition to the memory
#                 state_ = self.get_screen(state) #Transformed state
#                 nextState_ = get_screen(nextState)
                self.push(state, action, nextState, reward)

                # Mpve to next state    
                state = nextState   
                
                # Batch Optimization
                if self.memCntr >= self.batch_size:
                    self.optimize_model()             

                if done and info['ale.lives']==0:
                    reward = -100
                    # episode_durations.append(t+1)
                    # plot_durations()
                    break
                score += reward

            print('score:', score)
            print('')
            self.scores.append(score)
            
            if iEpisode % self.TARGET_UPDATE == 0:
                self.target_net.load_state_dict(self.policy_net.state_dict())

        print('======== Complete ========')

# %%
agent = Agent_DQN(env, args)
agent.train()
torch.save(agent.policy_net.state_dict(),'test')
# Out:
# Using device:  cuda
# hyperparameters and network initialized
# Episode:  0
# score: 0.0
#
# Episode:  1
# score: 1.0
#
# Episode:  2
# score: 0.0
#
# Episode:  3
# score: 0.0
#
# Episode:  4
# score: 0.0
#
# Episode:  5
# score: 0.0
#
# Episode:  6
# score: 0.0
#
# Episode:  7
# score: 0.0
#
# Episode:  8
# score: 0.0
#
# Episode:  9
# score: 0.0
#
# Episode:  10
# score: 0.0
#
# Episode:  11
# score: 0.0
#
# Episode:  12
# score: 0.0
#
# Episode:  13
# score: 0.0
#
# Episode:  14
# score: 0.0
#
# Episode:  15
# score: 0.0
#
# Episode:  16
# score: 0.0
#
# Episode:  17
# score: 2.0
#
# Episode:  18
# score: 1.0
#
# Episode:  19
# score: 1.0
#
# Episode:  20
# score: 1.0
#
# Episode:  21
# score: 1.0
#
# Episode:  22
# score: 2.0
#
# Episode:  23
# score: 1.0
#
# Episode:  24
# score: 1.0
#
# Episode:  25
# score: 1.0
#
# Episode:  26
# score: 1.0
#
# Episode:  27
# score: 0.0
#
# Episode:  28
# score: 0.0
#
# Episode:  29
# score: 0.0
#
# Episode:  30
# score: 0.0
#
# Episode:  31
# score: 0.0
#
# Episode:  32
# score: 0.0
#
# Episode:  33
# score: 0.0
#
# Episode:  34
# score: 0.0
#
# Episode:  35
# score: 0.0
#
# Episode:  36
# score: 0.0
#
# Episode:  37
# score: 0.0
#
# Episode:  38
# score: 0.0
#
# Episode:  39
# score: 0.0
#
# Episode:  40
# score: 0.0
#
# Episode:  41
# score: 0.0
#
# Episode:  42
# score: 2.0
#
# Episode:  43
# score: 1.0
#
# Episode:  44
# score: 1.0
#
# Episode:  45
# score: 0.0
#
# Episode:  46
# score: 1.0
#
# Episode:  47
# score: 0.0
#
# Episode:  48
# score: 0.0
#
# Episode:  49
# score: 0.0
#
# Episode:  50
# score: 0.0
#
# Episode:  51
# score: 0.0
#
# Episode:  52
# score: 0.0
#
# Episode:  53
# score: 0.0
#
# Episode:  54
# score: 0.0
#
# Episode:  55
# score: 0.0
#
# Episode:  56
# score: 0.0
#
# Episode:  57
# score: 0.0
#
# Episode:  58
# score: 0.0
#
# Episode:  59
# score: 0.0
#
# Episode:  60
# score: 0.0
#
# Episode:  61
# score: 0.0
#
# Episode:  62
# score: 0.0
#
# Episode:  63
# score: 0.0
#
# Episode:  64
# score: 0.0
#
# Episode:  65
# score: 0.0
#
# Episode:  66
# score: 0.0
#
# Episode:  67
# score: 0.0
#
# Episode:  68
# score: 0.0
#
# Episode:  69
# score: 0.0
#
# Episode:  70
# score: 0.0
#
# Episode:  71
# score: 0.0
#
# Episode:  72
# score: 0.0
#
# Episode:  73
# score: 0.0
#
# Episode:  74
# score: 0.0
#
# Episode:  75
# score: 0.0
#
# Episode:  76
# score: 0.0
#
# Episode:  77
# score: 0.0
#
# Episode:  78
# score: 0.0
#
# Episode:  79
# score: 0.0
#
# Episode:  80
# score: 0.0
#
# Episode:  81
# score: 0.0
#
# Episode:  82
# score: 0.0
#
# Episode:  83
# score: 0.0
#
# Episode:  84
# score: 0.0
#
# Episode:  85
# score: 0.0
#
# Episode:  86
# score: 0.0
#
# Episode:  87
# score: 0.0
#
# Episode:  88
# score: 0.0
#
# Episode:  89
# score: 0.0
#
# Episode:  90
# score: 0.0
#
# Episode:  91
# score: 0.0
#
# Episode:  92
# score: 2.0
#
# Episode:  93
# score: 1.0
#
# Episode:  94
# score: 1.0
#
# Episode:  95
# score: 1.0
#
# Episode:  96
# score: 1.0
#
# Episode:  97
# score: 0.0
#
# Episode:  98
# score: 0.0
#
# Episode:  99
# score: 0.0
#
# Episode:  100
# score: 0.0
#
# Episode:  101
# score: 0.0
#
# Episode:  102
# score: 0.0
#
# Episode:  103
# score: 0.0
#
# Episode:  104
# score: 0.0
#
# Episode:  105
# score: 0.0
#
# Episode:  106
# score: 0.0
#
# Episode:  107
# score: 0.0
#
# Episode:  108
# score: 0.0
#
# Episode:  109
# score: 0.0
#
# Episode:  110
# score: 0.0
#
# Episode:  111
# score: 0.0
#
# Episode:  112
# score: 0.0
#
# Episode:  113
# score: 0.0
#
# Episode:  114
# score: 0.0
#
# Episode:  115
# score: 0.0
#
# Episode:  116
# score: 0.0
#
# Episode:  117
# score: 2.0
#
# Episode:  118
# score: 1.0
#
# Episode:  119
# score: 1.0
#
# Episode:  120
# score: 1.0
#
# Episode:  121
# score: 1.0
#
# Episode:  122
# score: 2.0
#
# Episode:  123
# score: 1.0
#
# Episode:  124
# score: 1.0
#
# Episode:  125
# score: 0.0
#
# Episode:  126
# score: 1.0
#
# Episode:  127
# score: 0.0
#
# Episode:  128
# score: 0.0
#
# Episode:  129
# score: 0.0
#
# Episode:  130
# score: 0.0
#
# Episode:  131
# score: 0.0
#
# Episode:  132
# score: 0.0
#
# Episode:  133
# score: 0.0
#
# Episode:  134
# score: 0.0
#
# Episode:  135
# score: 0.0
#
# Episode:  136
# score: 0.0
#
# Episode:  137
# score: 0.0
#
# Episode:  138
# score: 0.0
#
# Episode:  139
# score: 0.0
#
# Episode:  140
# score: 0.0
#
# Episode:  141
# score: 0.0
#
# Episode:  142
# score: 0.0
#
# Episode:  143
# score: 0.0
#
# Episode:  144
# score: 0.0
#
# Episode:  145
# score: 0.0
#
# Episode:  146
# score: 0.0
#
# Episode:  147
# score: 2.0
#
# Episode:  148
# score: 1.0
#
# Episode:  149
# score: 1.0
#
# Episode:  150
# score: 1.0
#
# Episode:  151
# score: 1.0
#
# Episode:  152
# score: 0.0
#
# Episode:  153
# score: 0.0
#
# Episode:  154
# score: 0.0
#
# Episode:  155
# score: 0.0
#
# Episode:  156
# score: 0.0
#
# Episode:  157
# score: 0.0
#
# Episode:  158
# score: 0.0
#
# Episode:  159
# score: 0.0
#
# Episode:  160
# score: 0.0
#
# Episode:  161
# score: 0.0
#
# Episode:  162
# score: 0.0
#
# Episode:  163
# score: 0.0
#
# Episode:  164
# score: 0.0
#
# Episode:  165
# score: 0.0
#
# Episode:  166
# score: 0.0
#
# Episode:  167
# score: 2.0
#
# Episode:  168
# score: 1.0
#
# Episode:  169
# score: 1.0
#
# Episode:  170
# score: 1.0
#
# Episode:  171
# score: 1.0
#
# Episode:  172
# score: 0.0
#
# Episode:  173
# score: 0.0
#
# Episode:  174
# score: 0.0
#
# Episode:  175
# score: 0.0
#
# Episode:  176
# score: 0.0
#
# Episode:  177
# score: 2.0
#
# Episode:  178
# score: 1.0
#
# Episode:  179
# score: 1.0
#
# Episode:  180
# score: 1.0
#
# Episode:  181
# score: 1.0
#
# Episode:  182
# score: 0.0
#
# Episode:  183
# score: 0.0
#
# Episode:  184
# score: 0.0
#
# Episode:  185
# score: 0.0
#
# Episode:  186
# score: 0.0
#
# Episode:  187
# score: 0.0
#
# Episode:  188
# score: 0.0
#
# Episode:  189
# score: 0.0
#
# Episode:  190
# score: 0.0
#
# Episode:  191
# score: 0.0
#
# Episode:  192
# score: 0.0
#
# Episode:  193
# score: 0.0
#
# Episode:  194
# score: 0.0
#
# Episode:  195
# score: 0.0
#
# Episode:  196
# score: 0.0
#
# Episode:  197
# score: 0.0
#
# Episode:  198
# score: 0.0
#
# Episode:  199
# score: 0.0
#
# Episode:  200
# score: 0.0
#
# Episode:  201
# score: 0.0
#
# Episode:  202
# score: 0.0
#
# Episode:  203
# score: 0.0
#
# Episode:  204
# score: 0.0
#
# Episode:  205
# score: 0.0
#
# Episode:  206
# score: 0.0
#
# Episode:  207
# score: 0.0
#
# Episode:  208
# score: 0.0
#
# Episode:  209
# score: 0.0
#
# Episode:  210
# score: 0.0
#
# Episode:  211
# score: 0.0
#
# Episode:  212
# score: 0.0
#
# Episode:  213
# score: 0.0
#
# Episode:  214
# score: 0.0
#
# Episode:  215
# score: 0.0
#
# Episode:  216
# score: 0.0
#
# Episode:  217
# score: 2.0
#
# Episode:  218
# score: 1.0
#
# Episode:  219
# score: 1.0
#
# Episode:  220
# score: 1.0
#
# Episode:  221
# score: 1.0
#
# Episode:  222
# score: 0.0
#
# Episode:  223
# score: 0.0
#
# Episode:  224
# score: 0.0
#
# Episode:  225
# score: 0.0
#
# Episode:  226
# score: 0.0
#
# Episode:  227
# score: 0.0
#
# Episode:  228
# score: 0.0
#
# Episode:  229
# score: 0.0
#
# Episode:  230
# score: 0.0
#
# Episode:  231
# score: 0.0
#
# Episode:  232
# score: 0.0
#
# Episode:  233
# score: 0.0
#
# Episode:  234
# score: 0.0
#
# Episode:  235
# score: 0.0
#
# Episode:  236
# score: 0.0
#
# Episode:  237
# score: 0.0
#
# Episode:  238
# score: 0.0
#
# Episode:  239
# score: 0.0
#
# Episode:  240
# score: 0.0
#
# Episode:  241
# score: 0.0
#
# Episode:  242
# score: 0.0
#
# Episode:  243
# score: 0.0
#
# Episode:  244
# score: 0.0
#
# Episode:  245
# score: 0.0
#
# Episode:  246
# score: 0.0
#
# Episode:  247
# score: 0.0
#
# Episode:  248
# score: 0.0
#
# Episode:  249
# score: 0.0
#
# Episode:  250
# score: 0.0
#
# Episode:  251
# score: 0.0
#
# Episode:  252
# score: 0.0
#
# Episode:  253
# score: 0.0
#
# Episode:  254
# score: 0.0
#
# Episode:  255
# score: 0.0
#
# Episode:  256
# score: 0.0
#
# Episode:  257
# score: 2.0
#
# Episode:  258
# score: 1.0
#
# Episode:  259
# score: 1.0
#
# Episode:  260
# score: 1.0
#
# Episode:  261
# score: 1.0
#
# Episode:  262
# score: 0.0
#
# Episode:  263
# score: 0.0
#
# Episode:  264
# score: 0.0
#
# Episode:  265
# score: 0.0
#
# Episode:  266
# score: 0.0
#
# Episode:  267
# score: 2.0
#
# Episode:  268
# score: 1.0
#
# Episode:  269
# score: 1.0
#
# Episode:  270
# score: 1.0
#
# Episode:  271
# score: 1.0
#
# Episode:  272
# score: 2.0
#
# Episode:  273
# score: 1.0
#
# Episode:  274
# score: 1.0
#
# Episode:  275
# score: 1.0
#
# Episode:  276
# score: 1.0
#
# Episode:  277
# score: 0.0
#
# Episode:  278
# score: 0.0
#
# Episode:  279
# score: 0.0
#
# Episode:  280
# score: 0.0
#
# Episode:  281
# score: 0.0
#
# Episode:  282
# score: 0.0
#
# Episode:  283
# score: 0.0
#
# Episode:  284
# score: 0.0
#
# Episode:  285
# score: 0.0
#
# Episode:  286
# score: 0.0
#
# Episode:  287
# score: 0.0
#
# Episode:  288
# score: 0.0
#
# Episode:  289
# score: 0.0
#
# Episode:  290
# score: 0.0
#
# Episode:  291
# score: 0.0
#
# Episode:  292
# score: 2.0
#
# Episode:  293
# score: 1.0
#
# Episode:  294
# score: 1.0
#
# Episode:  295
# score: 1.0
#
# Episode:  296
# score: 1.0
#
# Episode:  297
# score: 0.0
#
# Episode:  298
# score: 0.0
#
# Episode:  299
# score: 0.0
#
# Episode:  300
# score: 0.0
#
# Episode:  301
# score: 0.0
#
# Episode:  302
# score: 2.0
#
# Episode:  303
# score: 1.0
#
# Episode:  304
# score: 1.0
#
# Episode:  305
# score: 1.0
#
# Episode:  306
# score: 1.0
#
# Episode:  307
# score: 0.0
#
# Episode:  308
# score: 0.0
#
# Episode:  309
# score: 0.0
#
# Episode:  310
# score: 0.0
#
# Episode:  311
# score: 0.0
#
# Episode:  312
# score: 0.0
#
# Episode:  313
# score: 0.0
#
# Episode:  314
# score: 0.0
#
# Episode:  315
# score: 0.0
#
# Episode:  316
# score: 0.0
#
# Episode:  317
# score: 0.0
#
# Episode:  318
# score: 0.0
#
# Episode:  319
# score: 0.0
#
# Episode:  320
# score: 0.0
#
# Episode:  321
# score: 0.0
#
# Episode:  322
# score: 0.0
#
# Episode:  323
# score: 0.0
#
# Episode:  324
# score: 0.0
#
# Episode:  325
# score: 0.0
#
# Episode:  326
# score: 0.0
#
# Episode:  327
# score: 0.0
#
# Episode:  328
# score: 0.0
#
# Episode:  329
# score: 0.0
#
# Episode:  330
# score: 0.0
#
# Episode:  331
# score: 0.0
#
# Episode:  332
# score: 0.0
#
# Episode:  333
# score: 0.0
#
# Episode:  334
# score: 0.0
#
# Episode:  335
# score: 0.0
#
# Episode:  336
# score: 0.0
#
# Episode:  337
# score: 0.0
#
# Episode:  338
# score: 0.0
#
# Episode:  339
# score: 0.0
#
# Episode:  340
# score: 0.0
#
# Episode:  341
# score: 0.0
#
# Episode:  342
# score: 0.0
#
# Episode:  343
# score: 0.0
#
# Episode:  344
# score: 0.0
#
# Episode:  345
# score: 0.0
#
# Episode:  346
# score: 0.0
#
# Episode:  347
# score: 0.0
#
# Episode:  348
# score: 0.0
#
# Episode:  349
# score: 0.0
#
# Episode:  350
# score: 0.0
#
# Episode:  351
# score: 0.0
#
# Episode:  352
# score: 0.0
#
# Episode:  353
# score: 0.0
#
# Episode:  354
# score: 0.0
#
# Episode:  355
# score: 0.0
#
# Episode:  356
# score: 0.0
#
# Episode:  357
# score: 0.0
#
# Episode:  358
# score: 0.0
#
# Episode:  359
# score: 0.0
#
# Episode:  360
# score: 0.0
#
# Episode:  361
# score: 0.0
#
# Episode:  362
# score: 0.0
#
# Episode:  363
# score: 0.0
#
# Episode:  364
# score: 0.0
#
# Episode:  365
# score: 0.0
#
# Episode:  366
# score: 0.0
#
# Episode:  367
# score: 0.0
#
# Episode:  368
# score: 0.0
#
# Episode:  369
# score: 0.0
#
# Episode:  370
# score: 0.0
#
# Episode:  371
# score: 0.0
#
# Episode:  372
# score: 0.0
#
# Episode:  373
# score: 0.0
#
# Episode:  374
# score: 0.0
#
# Episode:  375
# score: 0.0
#
# Episode:  376
# score: 0.0
#
# Episode:  377
# score: 0.0
#
# Episode:  378
# score: 0.0
#
# Episode:  379
# score: 0.0
#
# Episode:  380
# score: 0.0
#
# Episode:  381
# score: 0.0
#
# Episode:  382
# score: 0.0
#
# Episode:  383
# score: 0.0
#
# Episode:  384
# score: 0.0
#
# Episode:  385
# score: 0.0
#
# Episode:  386
# score: 0.0
#
# Episode:  387
# score: 0.0
#
# Episode:  388
# score: 0.0
#
# Episode:  389
# score: 0.0
#
# Episode:  390
# score: 0.0
#
# Episode:  391
# score: 0.0
#
# Episode:  392
# score: 0.0
#
# Episode:  393
# score: 0.0
#
# Episode:  394
# score: 0.0
#
# Episode:  395
# score: 0.0
#
# Episode:  396
# score: 0.0
#
# Episode:  397
# score: 0.0
#
# Episode:  398
# score: 0.0
#
# Episode:  399
# score: 0.0
#
# Episode:  400
# score: 0.0
#
# Episode:  401
# score: 0.0
#
# Episode:  402
# score: 0.0
#
# Episode:  403
# score: 0.0
#
# Episode:  404
# score: 0.0
#
# Episode:  405
# score: 0.0
#
# Episode:  406
# score: 0.0
#
# Episode:  407
# score: 0.0
#
# Episode:  408
# score: 0.0
#
# Episode:  409
# score: 0.0
#
# Episode:  410
# score: 0.0
#
# Episode:  411
# score: 0.0
#
# Episode:  412
# score: 0.0
#
# Episode:  413
# score: 0.0
#
# Episode:  414
# score: 0.0
#
# Episode:  415
# score: 0.0
#
# Episode:  416
# score: 0.0
#
# Episode:  417
# score: 2.0
#
# Episode:  418
# score: 1.0
#
# Episode:  419
# score: 1.0
#
# Episode:  420
# score: 1.0
#
# Episode:  421
# score: 1.0
#
# Episode:  422
# score: 0.0
#
# Episode:  423
# score: 0.0
#
# Episode:  424
# score: 0.0
#
# Episode:  425
# score: 0.0
#
# Episode:  426
# score: 0.0
#
# Episode:  427
# score: 0.0
#
# Episode:  428
# score: 0.0
#
# Episode:  429
# score: 0.0
#
# Episode:  430
# score: 0.0
#
# Episode:  431
# score: 0.0
#
# Episode:  432
# score: 0.0
#
# Episode:  433
# score: 0.0
#
# Episode:  434
# score: 0.0
#
# Episode:  435
# score: 0.0
#
# Episode:  436
# score: 0.0
#
# Episode:  437
# score: 0.0
#
# Episode:  438
# score: 0.0
#
# Episode:  439
# score: 0.0
#
# Episode:  440
# score: 0.0
#
# Episode:  441
# score: 0.0
#
# Episode:  442
# score: 0.0
#
# Episode:  443
# score: 0.0
#
# Episode:  444
# score: 0.0
#
# Episode:  445
# score: 0.0
#
# Episode:  446
# score: 0.0
#
# Episode:  447
# score: 2.0
#
# Episode:  448
# score: 1.0
#
# Episode:  449
# score: 1.0
#
# Episode:  450
# score: 1.0
#
# Episode:  451
# score: 1.0
#
# Episode:  452
# score: 0.0
#
# Episode:  453
# score: 0.0
#
# Episode:  454
# score: 0.0
#
# Episode:  455
# score: 0.0
#
# Episode:  456
# score: 0.0
#
# Episode:  457
# score: 0.0
#
# Episode:  458
# score: 0.0
#
# Episode:  459
# score: 0.0
#
# Episode:  460
# score: 0.0
#
# Episode:  461
# score: 0.0
#
# Episode:  462
# score: 0.0
#
# Episode:  463
# score: 0.0
#
# Episode:  464
# score: 0.0
#
# Episode:  465
# score: 0.0
#
# Episode:  466
# score: 0.0
#
# Episode:  467
# score: 0.0
#
# Episode:  468
# score: 0.0
#
# Episode:  469
# score: 0.0
#
# Episode:  470
# score: 0.0
#
# Episode:  471
# score: 0.0
#
# Episode:  472
# score: 2.0
#
# Episode:  473
# score: 1.0
#
# Episode:  474
# score: 1.0
#
# Episode:  475
# score: 1.0
#
# Episode:  476
# score: 1.0
#
# Episode:  477
# score: 0.0
#
# Episode:  478
# score: 0.0
#
# Episode:  479
# score: 0.0
#
# Episode:  480
# score: 0.0
#
# Episode:  481
# score: 0.0
#
# Episode:  482
# score: 2.0
#
# Episode:  483
# score: 1.0
#
# Episode:  484
# score: 1.0
#
# Episode:  485
# score: 1.0
#
# Episode:  486
# score: 1.0
#
# Episode:  487
# score: 0.0
#
# Episode:  488
# score: 0.0
#
# Episode:  489
# score: 0.0
#
# Episode:  490
# score: 0.0
#
# Episode:  491
# score: 0.0
#
# Episode:  492
# score: 0.0
#
# Episode:  493
# score: 0.0
#
# Episode:  494
# score: 0.0
#
# Episode:  495
# score: 0.0
#
# Episode:  496
# score: 0.0
#
# Episode:  497
# score: 2.0
#
# Episode:  498
# score: 1.0
#
# Episode:  499
# score: 1.0
#
# Episode:  500
# score: 1.0
#
# Episode:  501
# score: 1.0
#
# Episode:  502
# score: 0.0
#
# Episode:  503
# score: 0.0
#
# Episode:  504
# score: 0.0
#
# Episode:  505
# score: 0.0
#
# Episode:  506
# score: 0.0
#
# Episode:  507
# score: 0.0
#
# Episode:  508
# score: 0.0
#
# Episode:  509
# score: 0.0
#
# Episode:  510
# score: 0.0
#
# Episode:  511
# score: 0.0
#
# Episode:  512
# score: 0.0
#
# Episode:  513
# score: 0.0
#
# Episode:  514
# score: 0.0
#
# Episode:  515
# score: 0.0
#
# Episode:  516
# score: 0.0
#
# Episode:  517
# score: 0.0
#
# Episode:  518
# score: 0.0
#
# Episode:  519
# score: 0.0
#
# Episode:  520
# score: 0.0
#
# Episode:  521
# score: 0.0
#
# Episode:  522
# score: 2.0
#
# Episode:  523
# score: 1.0
#
# Episode:  524
# score: 1.0
#
# Episode:  525
# score: 1.0
#
# Episode:  526
# score: 1.0
#
# Episode:  527
# score: 0.0
#
# Episode:  528
# score: 0.0
#
# Episode:  529
# score: 0.0
#
# Episode:  530
# score: 0.0
#
# Episode:  531
# score: 0.0
#
# Episode:  532
# score: 0.0
#
# Episode:  533
# score: 0.0
#
# Episode:  534
# score: 0.0
#
# Episode:  535
# score: 0.0
#
# Episode:  536
# score: 0.0
#
# Episode:  537
# score: 0.0
#
# Episode:  538
# score: 0.0
#
# Episode:  539
# score: 0.0
#
# Episode:  540
# score: 0.0
#
# Episode:  541
# score: 0.0
#
# Episode:  542
# score: 0.0
#
# Episode:  543
# score: 0.0
#
# Episode:  544
# score: 0.0
#
# Episode:  545
# score: 0.0
#
# Episode:  546
# score: 0.0
#
# Episode:  547
# score: 0.0
#
# Episode:  548
# score: 0.0
#
# Episode:  549
# score: 0.0
#
# Episode:  550
# score: 0.0
#
# Episode:  551
# score: 0.0
#
# Episode:  552
# score: 0.0
#
# Episode:  553
# score: 0.0
#
# Episode:  554
# score: 0.0
#
# Episode:  555
# score: 0.0
#
# Episode:  556
# score: 0.0
#
# Episode:  557
# score: 0.0
#
# Episode:  558
# score: 0.0
#
# Episode:  559
# score: 0.0
#
# Episode:  560
# score: 0.0
#
# Episode:  561
# score: 0.0
#
# Episode:  562
# score: 0.0
#
# Episode:  563
# score: 0.0
#
# Episode:  564
# score: 0.0
#
# Episode:  565
# score: 0.0
#
# Episode:  566
# score: 0.0
#
# Episode:  567
# score: 0.0
#
# Episode:  568
# score: 0.0
#
# Episode:  569
# score: 0.0
#
# Episode:  570
# score: 0.0
#
# Episode:  571
# score: 0.0
#
# Episode:  572
# score: 0.0
#
# Episode:  573
# score: 0.0
#
# Episode:  574
# score: 0.0
#
# Episode:  575
# score: 0.0
#
# Episode:  576
# score: 0.0
#
# Episode:  577
# score: 2.0
#
# Episode:  578
# score: 1.0
#
# Episode:  579
# score: 1.0
#
# Episode:  580
# score: 1.0
#
# Episode:  581
# score: 1.0
#
# Episode:  582
# score: 0.0
#
# Episode:  583
# score: 0.0
#
# Episode:  584
# score: 0.0
#
# Episode:  585
# score: 0.0
#
# Episode:  586
# score: 0.0
#
# Episode:  587
# score: 0.0
#
# Episode:  588
# score: 0.0
#
# Episode:  589
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-156-2410155dc7d6> in <module>()
#       1 agent = Agent_DQN(env, args)
# ----> 2 agent.train()
#       3 torch.save(agent.policy_net.state_dict(),'test')
#
# <ipython-input-155-64adb57a307a> in train(self)
#     181                 # Batch Optimization
#     182                 if self.memCntr >= self.batch_size:
# --> 183                     self.optimize_model()
#     184
#     185                 if done and info['ale.lives']==0:
#
# <ipython-input-155-64adb57a307a> in optimize_model(self)
#     136
#     137         transitions = np.array(self.replay_buffer())
# --> 138         Qstate = self.policy_net.forward(list(transitions[:,0])).to(self.policy_net.device)
#     139         QNextState = self.policy_net.forward(list(transitions[:,2])).to(self.policy_net.device)
#     140
#
# <ipython-input-122-ca97c5b54c1e> in forward(self, observation)
#      53 #         observation = torch.Tensor(observation).unsqueeze(1)
#      54 #         print(observation.size())
# ---> 55         observation = torch.Tensor(observation).to(self.device)
#      56 #         observation = observation.reshape(observation.size(0),-1) # Shrinking the image
#      57         observation = self.conv1(observation)
#
# KeyboardInterrupt:

# %%
x= [i+1 for i in range(200)]
plt.plot(x,agent.scores)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-154-b9e5112a5dc5> in <module>()
#       1
#       2 x= [i+1 for i in range(200)]
# ----> 3 plt.plot(x,agent.scores)
#
# /usr/lib/python3/dist-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3259                       mplDeprecation)
#    3260     try:
# -> 3261         ret = ax.plot(*args, **kwargs)
#    3262     finally:
#    3263         ax._hold = washold
#
# /usr/lib/python3/dist-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1716                     warnings.warn(msg % (label_namer, func.__name__),
#    1717                                   RuntimeWarning, stacklevel=2)
# -> 1718             return func(ax, *args, **kwargs)
#    1719         pre_doc = inner.__doc__
#    1720         if pre_doc is None:
#
# /usr/lib/python3/dist-packages/matplotlib/axes/_axes.py in plot(self, *args, **kwargs)
#    1370         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1371
# -> 1372         for line in self._get_lines(*args, **kwargs):
#    1373             self.add_line(line)
#    1374             lines.append(line)
#
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     402                 this += args[0],
#     403                 args = args[1:]
# --> 404             for seg in self._plot_args(this, kwargs):
#     405                 yield seg
#     406
#
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     382             x, y = index_of(tup[-1])
#     383
# --> 384         x, y = self._xy_from_xy(x, y)
#     385
#     386         if self.command == 'plot':
#
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     241         if x.shape[0] != y.shape[0]:
#     242             raise ValueError("x and y must have same first dimension, but "
# --> 243                              "have shapes {} and {}".format(x.shape, y.shape))
#     244         if x.ndim > 2 or y.ndim > 2:
#     245             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (200,) and (202,)

# %%
agent = Agent_DQN(env, args)
T = Transition(1,1,1,1)
agent.push(*T)
for i in range(1,100):
    T = Transition(i,i+1,i*2,i/2)
    agent.push(*T)
print(np.shape(agent.memory))

minibatch = agent.replay_buffer()
print(np.shape(minibatch))
print(minibatch)
# Out:
# Using device:  cuda
# hyperparameters and network initialized
# (100, 4)
# (32, 4)
# [Transition(state=41, action=42, next_action=82, reward=20.5), Transition(state=29, action=30, next_action=58, reward=14.5), Transition(state=99, action=100, next_action=198, reward=49.5), Transition(state=95, action=96, next_action=190, reward=47.5), Transition(state=15, action=16, next_action=30, reward=7.5), Transition(state=22, action=23, next_action=44, reward=11.0), Transition(state=5, action=6, next_action=10, reward=2.5), Transition(state=91, action=92, next_action=182, reward=45.5), Transition(state=90, action=91, next_action=180, reward=45.0), Transition(state=2, action=3, next_action=4, reward=1.0), Transition(state=69, action=70, next_action=138, reward=34.5), Transition(state=7, action=8, next_action=14, reward=3.5), Transition(state=82, action=83, next_action=164, reward=41.0), Transition(state=77, action=78, next_action=154, reward=38.5), Transition(state=80, action=81, next_action=160, reward=40.0), Transition(state=75, action=76, next_action=150, reward=37.5), Transition(state=33, action=34, next_action=66, reward=16.5), Transition(state=9, action=10, next_action=18, reward=4.5), Transition(state=70, action=71, next_action=140, reward=35.0), Transition(state=16, action=17, next_action=32, reward=8.0), Transition(state=48, action=49, next_action=96, reward=24.0), Transition(state=52, action=53, next_action=104, reward=26.0), Transition(state=35, action=36, next_action=70, reward=17.5), Transition(state=71, action=72, next_action=142, reward=35.5), Transition(state=28, action=29, next_action=56, reward=14.0), Transition(state=11, action=12, next_action=22, reward=5.5), Transition(state=49, action=50, next_action=98, reward=24.5), Transition(state=14, action=15, next_action=28, reward=7.0), Transition(state=32, action=33, next_action=64, reward=16.0), Transition(state=64, action=65, next_action=128, reward=32.0), Transition(state=86, action=87, next_action=172, reward=43.0), Transition(state=19, action=20, next_action=38, reward=9.5)]

# %%
agent = Agent_DQN(env, args)
d = agent.policy_net.load_state_dict(torch.load('trainData'))
# Out:
# Using device:  cuda
# hyperparameters and network initialized
# ---------------------------------------------------
# RuntimeError      Traceback (most recent call last)
# <ipython-input-9-f96ec18e6b13> in <module>()
#       1 agent = Agent_DQN(env, args)
# ----> 2 d = agent.policy_net.load_state_dict(torch.load('trainData'))
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in load_state_dict(self, state_dict, strict)
#     775         if len(error_msgs) > 0:
#     776             raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
# --> 777                                self.__class__.__name__, "\n\t".join(error_msgs)))
#     778         return _IncompatibleKeys(missing_keys, unexpected_keys)
#     779
#
# RuntimeError: Error(s) in loading state_dict for DQN:
# 	Missing key(s) in state_dict: "conv1.0.weight", "conv1.0.bias", "conv2.0.weight", "conv2.0.bias", "conv3.0.weight", "conv3.0.bias", "fc1.weight", "fc1.bias", "fc2.weight", "fc2.bias".
# 	Unexpected key(s) in state_dict: "epoch", "model_state_dict", "optimizer_state_dict", "AvgRewards".

# %%
import csv

m = []
for i in range(100)
    m.append(i)
    
with open('employee_file.csv', mode='w') as employee_file:
    employee_writer = csv.writer(employee_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    employee_writer.add_scalar("m:",m)
